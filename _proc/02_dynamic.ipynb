# %% [raw]
# ---
# description: Fill in a module description here
# output-file: dynamic.html
# title: save dynamic data
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(save)
# Out:
# ---
#
# ### save
#
# >      save ()
