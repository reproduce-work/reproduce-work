# %% [raw]
# ---
# description: Fill in a module description here
# output-file: build.html
# title: build
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(main)
# Out:
# ---
#
# ### main
#
# >      main ()

# %%
#| echo: false
#| output: asis
show_doc(replace_inserts_with_toml_data)
# Out:
# ---
#
# ### replace_inserts_with_toml_data
#
# >      replace_inserts_with_toml_data (input_file, toml_file, output_file)

# %%
#| echo: false
#| output: asis
show_doc(read_base_config)
# Out:
# ---
#
# ### read_base_config
#
# >      read_base_config ()

# %%
#import os
#os.listdir(Path(os.getcwd()))
