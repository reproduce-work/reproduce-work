# %% [raw]
# ---
# description: An even newer description.
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(say_hello)
# Out:
# ---
#
# ### say_hello
#
# >      say_hello (to)
#
# Say hello to somebody
